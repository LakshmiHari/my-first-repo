# %% [markdown]
# physical components we can touch or able to see are Hardware components eg are cpu mouse keyboard monitor printer and so on..
#
# where as the tool which drives all of these can be mentioned as a software where we feel that presence but cant touch them .
